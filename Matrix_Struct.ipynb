# %%
import numpy as np
import math as m
np.set_printoptions(linewidth=np.inf)
from Matr import klocal,kglobal, orgElements,kglobal2f2,solveTruss,plotResults
from Matr3 import local3DFrame

# %%
# A=72;
# E=29000000;
# G=11154000;
# J=594;
# Iz=216;
# Iy=864;
# L=120;

# EK = local3DFrame(A,E,G,J,Iz,Iy,L)
# print(EK)

# %%
#Easy Inputs
# areas = np.array([[0.84,0.9,1,1,1.5]])
# coords = np.array([[0,0],[20,0],[13,15],[20,20]])
# moduli = np.array([[4000,4000,4000,4000,4000]])
# con = np.array([[1,2],[1,3],[3,2],[2,4],[3,4]])
# Bc = np.array([[1,1,0],[1,2,0],[2,2,0]])
# P = np.array([[4,2,-20],[4,1,5],[3,1,-12]])
# forceTable = solveTruss(Bc,P,coords, areas, moduli, con)[1]
# reactTable= solveTruss(Bc,P,coords, areas, moduli, con)[3]
# Rtable3 = solveTruss(Bc,P,coords, areas, moduli, con)[4]
# dispx = solveTruss(Bc,P,coords, areas, moduli, con)[6]
# dispy = solveTruss(Bc,P,coords, areas, moduli, con)[7]
# scale1 = 10

# plotResults(con,coords,scale1,dispx,dispy)

# %%
#Difficult Inputs
areas = np.array([[0.75,0.75,0.75,0.75,0.75,0.75,0.75,0.75,0.75,0.75]])
coords = np.array([[0,0],[120,0],[-40,60],[120,60],[50,110],[200,110]])
con = np.array([[1,3],[1,5],[1,4],[2,5],[2,4],[2,6],[3,5],[4,5],[4,6],[5,6]])
moduli = np.array([[125,125,125,125,125,125,125,125,125,125]])*1000
Bc = np.array([[1,1,0],[1,2,0],[2,1,0],[2,2,1]])
P = np.array([[3,1,500],[3,2,200],[6,2,-300]])
forceTable = solveTruss(Bc,P,coords, areas, moduli, con)[1]
reactTable= solveTruss(Bc,P,coords, areas, moduli, con)[3]
Rtable3 = solveTruss(Bc,P,coords, areas, moduli, con)[4]
dispx = solveTruss(Bc,P,coords, areas, moduli, con)[6]
dispy = solveTruss(Bc,P,coords, areas, moduli, con)[7]
scale1 = 10

plotResults(con,coords,scale1,dispx,dispy)
# Out:
# C:\Users\mucke\SE Materials\Steel\Matr.py:137: RuntimeWarning: divide by zero encountered in scalar divide
#   c1 = np.absolute(np.sin(np.arctan(ydif/xdif)))
# C:\Users\mucke\SE Materials\Steel\Matr.py:138: RuntimeWarning: divide by zero encountered in scalar divide
#   c2 = np.absolute(np.cos(np.arctan(ydif/xdif)))
